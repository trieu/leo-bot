# %% [markdown]
# # Movie recommendation system with Qdrant space vectors
#
# This notebook is a simple example of how to use Qdrant to build a movie recommendation system.
# We will use the MovieLens dataset and Qdrant to build a simple recommendation system.
#
# ## How it works
#
# MovieLens dataset contains a list of movies and ratings given by users. We will use this data to build a recommendation system.
#
# Our recommendation system will use an approach called **collaborative filtering**.
#
# The idea behind collaborative filtering is that if two users have similar tastes, then they will like similar movies.
# We will use this idea to find the most similar users to our own ratings and see what movies these similar users liked, which we haven't seen yet.
#
#
# 1. We will represent each user's ratings as a vector in a sparse high-dimensional space.
# 2. We will use Qdrant to index these vectors.
# 3. We will use Qdrant to find the most similar users to our own ratings.
# 4. We will see what movies these similar users liked, which we haven't seen yet.

# %%
# !pip install qdrant-client pandas
# Out:
# Requirement already satisfied: qdrant-client in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (1.7.3)
# Requirement already satisfied: pandas in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (1.59.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (1.59.0)
# Requirement already satisfied: httpx>=0.14.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx[http2]>=0.14.0->qdrant-client) (0.25.0)
# Requirement already satisfied: numpy>=1.21 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (1.26.4)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (2.8.2)
# Requirement already satisfied: pydantic>=1.10.8 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (1.10.14)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from qdrant-client) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: protobuf<5.0dev,>=4.21.6 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant-client) (4.24.4)
# Requirement already satisfied: setuptools in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant-client) (59.6.0)
# Requirement already satisfied: certifi in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (2023.7.22)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (0.18.0)
# Requirement already satisfied: idna in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (3.4)
# Requirement already satisfied: sniffio in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpx[http2]>=0.14.0->qdrant-client) (4.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant-client) (4.8.0)
# Requirement already satisfied: six>=1.5 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client) (4.0.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpcore<0.19.0,>=0.18.0->httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (3.7.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from httpcore<0.19.0,>=0.18.0->httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (0.14.0)
# Requirement already satisfied: exceptiongroup in /home/thomas/0-uspa/leo-bot/env/lib/python3.10/site-packages (from anyio<5.0,>=3.0->httpcore<0.19.0,>=0.18.0->httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (1.1.3)

# %%
# Download and unzip the dataset

# !mkdir -p data
# !wget https://files.grouplens.org/datasets/movielens/ml-1m.zip
# !unzip ml-1m.zip -d data
# Out:
# --2024-03-04 13:35:31--  https://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917549 (5.6M) [application/zip]
# Saving to: ‘ml-1m.zip.2’
#
# ml-1m.zip.2         100%[===================>]   5.64M  2.00MB/s    in 2.8s
#
# 2024-03-04 13:35:35 (2.00 MB/s) - ‘ml-1m.zip.2’ saved [5917549/5917549]
#
# Archive:  ml-1m.zip
# replace data/ml-1m/movies.dat? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
from qdrant_client import QdrantClient, models
import pandas as pd

# %%
users = pd.read_csv(
    './data/ml-1m/users.dat',
    sep='::',
    names=[
        'user_id',
        'gender',
        'age',
        'occupation',
        'zip'
    ],
    engine='python'
)
users
# Out:
#       user_id gender  age  occupation    zip
# 0           1      F    1          10  48067
# 1           2      M   56          16  70072
# 2           3      M   25          15  55117
# 3           4      M   45           7  02460
# 4           5      M   25          20  55455
# ...       ...    ...  ...         ...    ...
# 6035     6036      F   25          15  32603
# 6036     6037      F   45           1  76006
# 6037     6038      F   56           1  14706
# 6038     6039      F   45           0  01060
# 6039     6040      M   25           6  11106
#
# [6040 rows x 5 columns]

# %%
movies = pd.read_csv(
    './data/ml-1m/movies.dat',
    sep='::',
    names=[
        'movie_id',
        'title',
        'genres'
    ],
    engine='python',
    encoding='latin-1'
)
movies
# Out:
#       movie_id                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 3878      3948             Meet the Parents (2000)
# 3879      3949          Requiem for a Dream (2000)
# 3880      3950                    Tigerland (2000)
# 3881      3951             Two Family House (2000)
# 3882      3952               Contender, The (2000)
#
#                             genres
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# 3881                         Drama
# 3882                Drama|Thriller
#
# [3883 rows x 3 columns]

# %%
ratings = pd.read_csv(
    './data/ml-1m/ratings.dat',
    sep='::',
    names=[
        'user_id',
        'movie_id',
        'rating',
        'timestamp'
    ],
    engine='python'
)

# %%
# Normalize ratings

# Sparse vectors can use advantage of negative values, so we can normalize ratings to have mean 0 and std 1
# In this scenario we can take into account movies that we don't like

ratings.rating = (ratings.rating - ratings.rating.mean()) / ratings.rating.std()

# %%
# Convert ratings to sparse vectors

from collections import defaultdict

user_sparse_vectors = defaultdict(lambda: {
    "values": [],
    "indices": []
})

for row in ratings.itertuples():
    user_sparse_vectors[row.user_id]["values"].append(row.rating)
    user_sparse_vectors[row.user_id]["indices"].append(row.movie_id)

# %%
# For this small dataset we can use in-memory Qdrant
# But for production we recommend to use server-based version

qdrant = QdrantClient(":memory:") # or QdrantClient("http://localhost:6333")

# %%
# Create collection with configured sparse vectors
# Sparse vectors don't require to specify dimension, because it's extracted from the data automatically

qdrant.create_collection(
    "movielens",
    vectors_config={},
    sparse_vectors_config={
        "ratings": models.SparseVectorParams()
    }
)
# Out:
# True

# %%
# Upload all user's votes as sparse vectors

def data_generator():
    for user in users.itertuples():
        yield models.PointStruct(
            id=user.user_id,
            vector={
                "ratings": user_sparse_vectors[user.user_id]
            },
            payload=user._asdict()
        )

# This will do lazy upload of the data
qdrant.upload_records(
    "movielens",
    data_generator()
)
# Out:
# /tmp/ipykernel_182096/2959165938.py:14: DeprecationWarning: `upload_records` is deprecated, use `upload_points` instead
#   qdrant.upload_records(

# %%
# Let's try to recommend something for ourselves

#  1 - like
# -1 - dislike

# Search with 
# movies[movies.title.str.contains("Matrix", case=False)]

my_ratings = { 
    2571: 1,  # Matrix
    329: 1,   # Star Trek
    260: 1,   # Star Wars
    2288: -1, # The Thing
    1: 1,     # Toy Story
    1721: -1, # Titanic
    296: -1,  # Pulp Fiction
    356: 1,   # Forrest Gump
    2116: 1,  # Lord of the Rings
    1291: -1, # Indiana Jones
    1036: -1  # Die Hard
}

inverse_ratings = {k: -v for k, v in my_ratings.items()}

def to_vector(ratings):
    vector = models.SparseVector(
        values=[],
        indices=[]
    )
    for movie_id, rating in ratings.items():
        vector.values.append(rating)
        vector.indices.append(movie_id)
    return vector

# %%
# Find users with similar taste

results = qdrant.search(
    "movielens",
    query_vector=models.NamedSparseVector(
        name="ratings",
        vector=to_vector(my_ratings)
    ),
    with_vectors=True, # We will use those to find new movies
    limit=20
)

# %%
# Calculate how frequently each movie is found in similar users' ratings

def results_to_scores(results):
    movie_scores = defaultdict(lambda: 0)

    for user in results:
        user_scores = user.vector['ratings']
        for idx, rating in zip(user_scores.indices, user_scores.values):
            if idx in my_ratings:
                continue
            movie_scores[idx] += rating

    return movie_scores

# %%
# Sort movies by score and print top 5

movie_scores = results_to_scores(results)
top_movies = sorted(movie_scores.items(), key=lambda x: x[1], reverse=True)

for movie_id, score in top_movies[:5]:
    print(movies[movies.movie_id == movie_id].title.values[0], score)

# %%
# Find users with similar taste, but only within my age group
# We can also filter by other fields, like `gender`, `occupation`, etc.

results = qdrant.search(
    "movielens",
    query_vector=models.NamedSparseVector(
        name="ratings",
        vector=to_vector(my_ratings)
    ),
    query_filter=models.Filter(
        must=[
            models.FieldCondition(
                key="user_id",
                match=models.MatchValue(value=5)
            )
        ]
    ),
    with_vectors=True,
    limit=20
)

movie_scores = results_to_scores(results)
top_movies = sorted(movie_scores.items(), key=lambda x: x[1], reverse=True)

for movie_id, score in top_movies[:5]:
    print(movies[movies.movie_id == movie_id].title.values[0], score)
# Out:
# City of Lost Children, The (1995) 1.2697459527485968
# Usual Suspects, The (1995) 1.2697459527485968
# Maltese Falcon, The (1941) 1.2697459527485968
# Big Night (1996) 1.2697459527485968
# Beautiful Thing (1996) 1.2697459527485968
